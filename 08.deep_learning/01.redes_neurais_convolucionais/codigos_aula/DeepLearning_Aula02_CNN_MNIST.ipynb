# %% [markdown]
# # Rede Neural Convolucional com Keras
#
# Neste exercício, vamos construir uma rede neural convolucional (CNN) para classificar os digitos do MNIST.

# %% [markdown]
# ![http://cs231n.github.io/convolutional-networks/](https://hackernoon.com/hn-images/0*9J3MK1gd2zrFDzDN.gif)
#
# Source: http://cs231n.github.io/convolutional-networks/

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras

# %% [markdown]
# ## Camada Convolucional

# %% [markdown]
# # Carregar dados para treinamento
#
# ## Pré-processamento dos dados para treinamento:
#
# Diferentemente do que fizemos na nossa rede neural, a entrada da CNN é uma imagem, então não é necessário transformar a imagem em um vetor. No entanto, precisamos informar nossa rede quanto às dimensões das nossas imagens. Imagens coloridas normalmente têm 3 canais (RGB), mas estamos trabalhando com imagens em escala de cinza, que contém apenas um canal. **Importante**, O Tensorflow assume que o número de canais sempre está na última dimensão da imagem, enquanto o Pyorch assume a primeira dimensão:
#
# ```
# Tensorflow -> (img_rows, img_cols, channels)
# Pytorch -> (channels, img_rows, img_cols)
# ```
#
# Além disso, nós escalamos as entradas para estarem no intervalo [0-1] ao invés de [0-255]. **Outros tipos de pré-processamento, como dimensionamento, normalização e cortes podem ser feitos nessa parte.**

# %%
mnist = tf.keras.datasets.mnist

# Carrega os dados, que já vem divididos em conjunto de treinamento e teste.
(x_trainVal, y_trainVal), (x_test, y_test) = mnist.load_data()

# Embaralha os dados e divide em 80% para treino, 20% para validação
nData = x_trainVal.shape[0]
nTrain = int(nData * 0.8)
randomIdx = np.random.permutation(np.arange(nData))
trainIdx = randomIdx[:nTrain]
valIdx = randomIdx[nTrain:]

# Divide os dados
x_val, y_val = x_trainVal[valIdx], y_trainVal[valIdx]
x_train, y_train = x_trainVal[trainIdx], y_trainVal[trainIdx]

# Normaliza dados entre [0, 1]
x_train = x_train / 255.0
x_val = x_val / 255.0
x_test = x_test / 255.0

print("Formato das imagens de treinamento", x_train.shape)
print("Formato dos rótulos de treinamento", y_train.shape)
print()

print("Formato das imagens de validação", x_val.shape)
print("Formato dos rótulos de validação", y_val.shape)


# Adiciona um canal no treino (H, W, C)
x_train = x_train[..., tf.newaxis] # quer dizer que vai ficar tudo igual, mas no fim vai adicionar mais o novo eixo tf.newaxis
x_val = x_val[..., tf.newaxis]
x_test = x_test[..., tf.newaxis]

# One hot encoding dos labels
num_classes = len(np.unique(y_train))
y_train_oh = tf.keras.utils.to_categorical(y_train, num_classes)
y_val_oh = tf.keras.utils.to_categorical(y_val, num_classes)
y_test_oh = tf.keras.utils.to_categorical(y_test, num_classes)
print(x_train.shape, y_train_oh.shape)
# Out:
# Formato das imagens de treinamento (48000, 28, 28)
# Formato dos rótulos de treinamento (48000,)
#
# Formato das imagens de validação (12000, 28, 28)
# Formato dos rótulos de validação (12000,)
# (48000, 28, 28, 1) (48000, 10)

# %% [markdown]
# ## Nosso treino é balanceado?
#
# Para cada classe, vamos checar quantos exemplos temos e calcular um peso. Isso pode ser útil para dizer ao modelo "prestar mais atenção" em amostras de uma classe com menos indivíduos durante o treinamento.

# %%
# Para o conjunto de treino
unique, counts = np.unique(y_train, return_counts=True)
print("Treino ---> ", dict(zip(unique, counts)), "\n")

from sklearn.utils.class_weight import compute_class_weight
class_weights = compute_class_weight(class_weight='balanced',
                                     classes=np.unique(y_train),
                                     y=y_train)
train_class_weights = dict(enumerate(class_weights)) #peso de classe só com os dados de treinamento, para não ter leakage
print(train_class_weights, "\n")

#Para o conjunto de teste ---> Nós usamos isso para calcular a acurácia normalizada
unique, counts = np.unique(y_test, return_counts=True)
print("Teste  ---> ", dict(zip(unique, counts)), "\n")
# Out:
# Treino --->  {0: 4723, 1: 5391, 2: 4728, 3: 4899, 4: 4669, 5: 4365, 6: 4713, 7: 5062, 8: 4697, 9: 4753}
#
# {0: 1.0163031971204743, 1: 0.8903728436282693, 2: 1.015228426395939, 3: 0.9797917942437232, 4: 1.0280573998714928, 5: 1.0996563573883162, 6: 1.0184595798854232, 7: 0.9482418016594232, 8: 1.0219288907813497, 9: 1.0098884914790658}
#
# Teste  --->  {0: 980, 1: 1135, 2: 1032, 3: 1010, 4: 982, 5: 892, 6: 958, 7: 1028, 8: 974, 9: 1009}

# %%
from tensorflow.keras import layers

model = tf.keras.Sequential()
#Camada convolucional com 10 filtros de tamanho 3x3 e ativação ReLU
model.add(layers.Conv2D(10, 3, padding='valid', activation='relu', input_shape=(28, 28, 1)))
#Max pooling de tamanho 2x2
model.add(layers.MaxPooling2D(pool_size=(2,2)))
#Operação de vetorização dos dados
model.add(layers.Flatten())
#Densa com 10 nós de saída
model.add(layers.Dense(10)) #Camada densa é um MLP

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 10)        100
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 10)        0
#  D)
#
#  flatten (Flatten)           (None, 1690)              0
#
#  dense (Dense)               (None, 10)                16910
#
# =================================================================
# Total params: 17010 (66.45 KB)
# Trainable params: 17010 (66.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Visualizando a rede

# %%
# !pip3 install visualkeras # Instalação do pacote visualkeras para visualização
# Para saber sobre mais pacotes de visualização: https://github.com/ashishpatel26/Tools-to-Design-or-Visualize-Architecture-of-Neural-Network
# Out:
# Requirement already satisfied: visualkeras in /usr/local/lib/python3.10/dist-packages (0.0.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.23.5)
# Requirement already satisfied: aggdraw>=1.3.11 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.3.18)

# %%
import visualkeras

visualkeras.layered_view(model).show() # visualizando a rede
visualkeras.layered_view(model)

#visualkeras.layered_view(model, to_file='output.png') # para salvar
#visualkeras.layered_view(model, to_file='output.png').show() # para salvar e mostrar
# Out:
# <PIL.Image.Image image mode=RGBA size=300x139>

# %% [markdown]
# ## Compile o modelo
#
# Vamos definir a função de perda e o otimizador que usaremos para treinar nossa CNN, assim como especifiar que queremos salvar a acurácia em cada época. Usaremos a função de "categorical cross-entropy" como função de perda, e o otimizador SGD (Stochastic Gradient Descent). **Lembre-se que o Keras não retorna a acurácia normalizada!!**

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ## Treine o modelo!
#
# Nós já estamos prontos para treinar nossa CNN! A função `model.fit` recebe os argumentos:
# - **x_train & y_train_oh:** os dados de treino e suas classes.
# - **epochs:** uma época ocorre a cada vez que **todos** seus dados de treino passam pela rede uma vez. Como CNNs são mais caras em termos computacionais que redes neurais simples, nós vamos processar apenas 1 época.
# - **batch_size:** ao invés de otimizar sua rede em todos os dads de treino de uma só vez, nós normalmente otimizamos utilizando batches (pequeno conjunto pertencente aos dados de treino). Neste caso, nós iremos atualizar nossos pesos (backpropagation) depois do passo de "forward" (processamento do batch de 128 imagens);
# - **class_weight:** os pesos de cada classe, considerando que elas não são balanceadas. Este parâmetro é responsável por ponderar a loss de acordo com a frequência de ocorrência de cada classe.
# - **validation_data:** depois de cada época nosso modelo vai predizer esses dados, e retornar o resultado da função de perda, e a acurácia em relação a eles.

# %%
model.fit(x_train, y_train_oh, epochs=50, batch_size=32, class_weight=train_class_weights,
          validation_data=(x_val, y_val_oh))
# Out:
# Epoch 1/50
# 1500/1500 [==============================] - 10s 4ms/step - loss: 2.0330 - accuracy: 0.4031 - val_loss: 1.5159 - val_accuracy: 0.7345
# Epoch 2/50
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.9587 - accuracy: 0.8049 - val_loss: 0.6458 - val_accuracy: 0.8360
# Epoch 3/50
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.5483 - accuracy: 0.8572 - val_loss: 0.4901 - val_accuracy: 0.8636
# Epoch 4/50
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.4514 - accuracy: 0.8750 - val_loss: 0.4334 - val_accuracy: 0.8741
# Epoch 5/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4093 - accuracy: 0.8852 - val_loss: 0.4042 - val_accuracy: 0.8813
# Epoch 6/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3849 - accuracy: 0.8904 - val_loss: 0.3856 - val_accuracy: 0.8857
# Epoch 7/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3687 - accuracy: 0.8952 - val_loss: 0.3740 - val_accuracy: 0.8897
# Epoch 8/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3571 - accuracy: 0.8976 - val_loss: 0.3639 - val_accuracy: 0.8933
# Epoch 9/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3478 - accuracy: 0.9011 - val_loss: 0.3561 - val_accuracy: 0.8968
# Epoch 10/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3409 - accuracy: 0.9024 - val_loss: 0.3490 - val_accuracy: 0.8986
# Epoch 11/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3347 - accuracy: 0.9041 - val_loss: 0.3439 - val_accuracy: 0.9004
# Epoch 12/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3297 - accuracy: 0.9057 - val_loss: 0.3383 - val_accuracy: 0.9004
# Epoch 13/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3252 - accuracy: 0.9066 - val_loss: 0.3336 - val_accuracy: 0.9025
# Epoch 14/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3211 - accuracy: 0.9085 - val_loss: 0.3308 - val_accuracy: 0.9024
# Epoch 15/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3175 - accuracy: 0.9094 - val_loss: 0.3266 - val_accuracy: 0.9045
# Epoch 16/50
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.3144 - accuracy: 0.9103 - val_loss: 0.3241 - val_accuracy: 0.9061
# Epoch 17/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3112 - accuracy: 0.9113 - val_loss: 0.3231 - val_accuracy: 0.9057
# Epoch 18/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3084 - accuracy: 0.9120 - val_loss: 0.3192 - val_accuracy: 0.9062
# Epoch 19/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3060 - accuracy: 0.9128 - val_loss: 0.3164 - val_accuracy: 0.9074
# Epoch 20/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.3034 - accuracy: 0.9133 - val_loss: 0.3144 - val_accuracy: 0.9078
# Epoch 21/50
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.3011 - accuracy: 0.9140 - val_loss: 0.3130 - val_accuracy: 0.9083
# Epoch 22/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2990 - accuracy: 0.9149 - val_loss: 0.3103 - val_accuracy: 0.9098
# Epoch 23/50
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2968 - accuracy: 0.9159 - val_loss: 0.3091 - val_accuracy: 0.9101
# Epoch 24/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2950 - accuracy: 0.9160 - val_loss: 0.3079 - val_accuracy: 0.9093
# Epoch 25/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2932 - accuracy: 0.9164 - val_loss: 0.3043 - val_accuracy: 0.9112
# Epoch 26/50
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.2912 - accuracy: 0.9172 - val_loss: 0.3039 - val_accuracy: 0.9105
# Epoch 27/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2896 - accuracy: 0.9179 - val_loss: 0.3022 - val_accuracy: 0.9121
# Epoch 28/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2879 - accuracy: 0.9186 - val_loss: 0.3010 - val_accuracy: 0.9107
# Epoch 29/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2864 - accuracy: 0.9191 - val_loss: 0.2984 - val_accuracy: 0.9124
# Epoch 30/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2847 - accuracy: 0.9194 - val_loss: 0.2973 - val_accuracy: 0.9128
# Epoch 31/50
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.2832 - accuracy: 0.9197 - val_loss: 0.2966 - val_accuracy: 0.9128
# Epoch 32/50
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.2819 - accuracy: 0.9207 - val_loss: 0.2947 - val_accuracy: 0.9133
# Epoch 33/50
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.2803 - accuracy: 0.9204 - val_loss: 0.2960 - val_accuracy: 0.9143
# Epoch 34/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2792 - accuracy: 0.9211 - val_loss: 0.2917 - val_accuracy: 0.9142
# Epoch 35/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2776 - accuracy: 0.9211 - val_loss: 0.2909 - val_accuracy: 0.9153
# Epoch 36/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2763 - accuracy: 0.9219 - val_loss: 0.2894 - val_accuracy: 0.9147
# Epoch 37/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2748 - accuracy: 0.9220 - val_loss: 0.2895 - val_accuracy: 0.9156
# Epoch 38/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2736 - accuracy: 0.9228 - val_loss: 0.2875 - val_accuracy: 0.9153
# Epoch 39/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2724 - accuracy: 0.9227 - val_loss: 0.2860 - val_accuracy: 0.9153
# Epoch 40/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2710 - accuracy: 0.9236 - val_loss: 0.2844 - val_accuracy: 0.9157
# Epoch 41/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2696 - accuracy: 0.9238 - val_loss: 0.2837 - val_accuracy: 0.9168
# Epoch 42/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2685 - accuracy: 0.9240 - val_loss: 0.2822 - val_accuracy: 0.9171
# Epoch 43/50
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2671 - accuracy: 0.9244 - val_loss: 0.2821 - val_accuracy: 0.9171
# Epoch 44/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2658 - accuracy: 0.9249 - val_loss: 0.2797 - val_accuracy: 0.9172
# Epoch 45/50
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.2647 - accuracy: 0.9251 - val_loss: 0.2795 - val_accuracy: 0.9183
# Epoch 46/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2631 - accuracy: 0.9259 - val_loss: 0.2785 - val_accuracy: 0.9184
# Epoch 47/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2620 - accuracy: 0.9258 - val_loss: 0.2763 - val_accuracy: 0.9199
# Epoch 48/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2606 - accuracy: 0.9266 - val_loss: 0.2749 - val_accuracy: 0.9197
# Epoch 49/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2593 - accuracy: 0.9272 - val_loss: 0.2752 - val_accuracy: 0.9204
# Epoch 50/50
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2580 - accuracy: 0.9272 - val_loss: 0.2734 - val_accuracy: 0.9208

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
np.set_printoptions(precision=4,suppress=True)

# Faz as predições para o conjunto de teste
predictions = model.predict(x_test)
#score = model.evaluate(x_test, y_test_oh, verbose=1) # Poderia ser usado se o objetivo é ter apenas a métrica.

# Matriz de confusão
cm = confusion_matrix(np.argmax(predictions, axis=1), y_test)
print("Matriz de confusão")
plt.figure(figsize = (11,9))
sns.set(font_scale=0.9)
sns.heatmap(cm, annot=True, fmt='g', cmap='viridis')
# Out:
# 313/313 [==============================] - 1s 2ms/step
# Matriz de confusão
# <Axes: >

# %%
# Matriz de confusão normalizada
cmn = cm / cm.astype(float).sum(axis=1, keepdims=True)
balanced_acc = np.trace(cmn) / num_classes
print("\n\nAcurácia balanceada:", balanced_acc)

print("\n\nMatriz de confusão balanceada")
plt.figure(figsize = (11,9))
sns.set(font_scale=0.9)
sns.heatmap(cmn, annot=True, fmt='.1%', cmap='viridis')
# Out:
# Acurácia balanceada: 0.9282742006232073
#
#
# Matriz de confusão balanceada
# <Axes: >

# %% [markdown]
# ## Cuidado!
# - Número de épocas muito baixo. Nunca fazemos o treinamento de uma rede usando apenas 1 época.
# - Múltiplas avaliações do conjunto de teste. Lembre-se, as avaliações são feitas no conjunto de validação. O teste deve ser usado uma ÚNICA vez.
# - Número de camadas != Número de filtros
